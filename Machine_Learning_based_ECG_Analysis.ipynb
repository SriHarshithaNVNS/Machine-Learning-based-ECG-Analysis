# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.utils import resample
from scipy.signal import resample as scipy_resample
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix
random_seed = 1024
import numpy as np # linear algebra
np.random.seed(random_seed)

# %%
mitbih_train_loc = "mitbih_train.csv"
mitbih_test_loc = "mitbih_test.csv"
mitbih_train_df = pd.read_csv(mitbih_train_loc, header=None)
mitbih_test_df = pd.read_csv(mitbih_test_loc, header=None)
dataset = pd.concat([mitbih_train_df, mitbih_test_df], axis=0, sort=True).reset_index(drop=True)

# %%
labels = dataset.iloc[:, -1].astype('category').map({
    0: 'N - Normal Beat',
    1: 'S - Supraventricular premature or ectopic beat',
    2: 'V - Premature ventricular contraction',
    3: 'F - Fusion of ventricular and normal beat',
    4: 'Q - Unclassified beat'})

# %%
obs = np.array(dataset.iloc[:, :187])

# %%
n_indexes = labels.index[labels == 'N - Normal Beat']
q_indexes = labels.index[labels == 'Q - Unclassified beat']
v_indexes = labels.index[labels == 'V - Premature ventricular contraction']
s_indexes = labels.index[labels == 'S - Supraventricular premature or ectopic beat']
f_indexes = labels.index[labels == 'F - Fusion of ventricular and normal beat']

# sample one observation per class by indexing the train_labels
n_index = n_indexes[0]
q_index = q_indexes[0]
v_index = v_indexes[0]
s_index = s_indexes[0]
f_index = f_indexes[0]

def generate_subplot(figure, obs, gridspec, row, col, title):
    axis = figure.add_subplot(gridspec[row, col])
    axis.plot(np.linspace(0, 1, obs.shape[0]), obs)
    axis.set_title(title)

fig = plt.figure(figsize=(12, 8))
fig.subplots_adjust(hspace=0.5, wspace=0.001)
gs = fig.add_gridspec(5, 1)

generate_subplot(fig, obs[n_index], gs, 0, 0, 'N - Normal Beat')
generate_subplot(fig, obs[q_index], gs, 1, 0, 'Q - Unclassified beat')
generate_subplot(fig, obs[v_index], gs, 2, 0, 'V - Premature ventricular contraction')
generate_subplot(fig, obs[s_index], gs, 3, 0, 'S - Supraventricular premature or ectopic beat')
generate_subplot(fig, obs[f_index], gs, 4, 0, 'F - Fusion of ventricular and normal beat')

plt.show()

# %%
observation_counts = labels.value_counts()
labels_descending = np.array(observation_counts.keys())

fig1, ax1 = plt.subplots()
ax1.pie(observation_counts, labels=labels_descending, autopct='%1.1f%%', startangle=0, shadow=True)
ax1.axis('equal')
fig1.set_size_inches(12,8)
ax1.set_title("Percentage Distribution of Heartbeat Classes", fontsize=20)
plt.show()

# %%
print(observation_counts)
# Out:
# 187
# N - Normal Beat                                   90589
# Q - Unclassified beat                              8039
# V - Premature ventricular contraction              7236
# S - Supraventricular premature or ectopic beat     2779
# F - Fusion of ventricular and normal beat           803
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

random_seed = 42  # Or any seed value you want

# Resample indexes of each class
n_indexes_resampled = resample(n_indexes, replace=True, n_samples=10000, random_state=random_seed)
q_indexes_resampled = resample(q_indexes, replace=True, n_samples=10000, random_state=random_seed)
v_indexes_resampled = resample(v_indexes, replace=True, n_samples=10000, random_state=random_seed)
s_indexes_resampled = resample(s_indexes, replace=True, n_samples=10000, random_state=random_seed)
f_indexes_resampled = resample(f_indexes, replace=True, n_samples=10000, random_state=random_seed)

# Initialize the labels_resampled to empty pandas Series
labels_resampled = pd.Series(dtype=labels.dtype)

# Initialize obs_resampled as an empty array with the correct number of features
obs_resampled = np.empty((0, obs.shape[1]), dtype=obs.dtype)

#  List of resampled indexes
label_indexes_list = [n_indexes_resampled,
                      q_indexes_resampled,
                      v_indexes_resampled,
                      s_indexes_resampled,
                      f_indexes_resampled]

for label_indexes in label_indexes_list:
    # Append labels for all resampled classes
    labels_resampled = pd.concat([labels_resampled, labels[label_indexes]], ignore_index=True)

    # Append observations for all resampled classes
    obs_resampled = np.concatenate((obs_resampled, obs[label_indexes]), axis=0)

# %%
observation_counts = labels_resampled.value_counts()
labels_descending = np.array(observation_counts.keys())

fig1, ax1 = plt.subplots()
ax1.pie(observation_counts, labels=labels_descending, autopct='%1.1f%%', startangle=0, shadow=True)
ax1.axis('equal')
fig1.set_size_inches(12,8)
ax1.set_title("Percentage Distribution of Heartbeat Classes (Resampled)", fontsize=20)
plt.show()

# %%
print(observation_counts)
# Out:
# N - Normal Beat                                   10000
# S - Supraventricular premature or ectopic beat    10000
# V - Premature ventricular contraction             10000
# F - Fusion of ventricular and normal beat         10000
# Q - Unclassified beat                             10000
# Name: count, dtype: int64

# %%
from scipy.signal import resample

# first version of adding random noise (Gaussian Noise)
mean = 0
std = 0.05
def add_gaussian_noise(signal):
    noise = np.random.normal(mean, std, signal.shape)
    return signal + noise

def stretch(x):
    l = int(x.shape[0] * (1 + (random.random() - 0.5) / 3))
    y = scipy_resample(x, l)
    if l < x.shape[0]:
        y_ = np.zeros(x.shape)
        y_[:l] = y
    else:
        y_ = y[:x.shape[0]]
    return y_

def amplify(x):
    alpha = (random.random() - 0.5)
    factor = -alpha * x + (1 + alpha)
    return x * factor

def add_amplify_and_stretch_noise(x):
    if random.random() < 0.33:
        return stretch(x)
    elif random.random() < 0.66:
        return amplify(x)
    else:
        return amplify(stretch(x))

obs_resampled_with_noise_1 = np.array([add_gaussian_noise(obs) for obs in obs_resampled])
obs_resampled_with_noise_2 = np.array([add_amplify_and_stretch_noise(obs) for obs in obs_resampled])

# %%
def generate_plots_for_a_specific_data_augmentation(obs_resampled, obs_resampled_with_noise_1, obs_resampled_with_noise_2):
    # Sample one observation per class by indexing the train_labels
    n_index = 0
    q_index = 10000
    v_index = 20000
    s_index = 30000
    f_index = 40000

    fig = plt.figure(figsize=(15, 15))
    fig.subplots_adjust(hspace=0.5, wspace=0.001)
    gs = fig.add_gridspec(5, 3)

    generate_subplot(fig, obs_resampled[n_index], gs, 0, 0, 'N - Normal Beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[n_index], gs, 0, 1, 'N - Normal Beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[n_index], gs, 0, 2, 'N - Normal Beat \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[q_index], gs, 1, 0, 'Q - Unclassified beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[q_index], gs, 1, 1, 'Q - Unclassified beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[q_index], gs, 1, 2, 'Q - Unclassified beat \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[v_index], gs, 2, 0, 'V - Premature ventricular contraction \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[v_index], gs, 2, 1, 'V - Premature ventricular contraction \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[v_index], gs, 2, 2, 'V - Premature ventricular contraction \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[s_index], gs, 3, 0, 'S - Supraventricular premature or ectopic beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[s_index], gs, 3, 1, 'S - Supraventricular premature or ectopic beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[s_index], gs, 3, 2, 'S - Supraventricular premature or ectopic beat \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[f_index], gs, 4, 0, 'F - Fusion of ventricular and normal beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[f_index], gs, 4, 1, 'F - Fusion of ventricular and normal beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[f_index], gs, 4, 2, 'F - Fusion of ventricular and normal beat \n(with random noise v2)')

    plt.show()

generate_plots_for_a_specific_data_augmentation(obs_resampled, obs_resampled_with_noise_1, obs_resampled_with_noise_2)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# Prepare the final dataset for training
obs_resampled_final = np.concatenate((obs_resampled, obs_resampled_with_noise_1, obs_resampled_with_noise_2), axis=0)
labels_resampled_final = pd.concat([labels_resampled, labels_resampled, labels_resampled], ignore_index=True)

# Convert labels to numeric format (if not already)
label_mapping = {label: idx for idx, label in enumerate(labels_resampled_final.unique())}
labels_numeric = labels_resampled_final.map(label_mapping).values

# Split the data
X_train, X_test, y_train, y_test = train_test_split(obs_resampled_final, labels_numeric, test_size=0.2, random_state=42)

# Define the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(label_mapping), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=300, validation_split=0.2, batch_size=100)

# Make predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=label_mapping.keys())

# Print the results
print(f'Test Accuracy (Overall): {accuracy * 100:.2f}%')
print(report)

# Generate individual class accuracies
unique_labels = np.unique(y_test)
class_accuracies = {}

for label in unique_labels:
    label_idx = (y_test == label)
    class_accuracy = accuracy_score(y_test[label_idx], y_pred[label_idx])
    class_accuracies[label] = class_accuracy

for label, acc in class_accuracies.items():
    print(f'Test Accuracy of {list(label_mapping.keys())[label]}: {acc * 100:.2f}% ({sum(y_test == label)}/{len(y_test)})')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7311 - loss: 0.7311 - val_accuracy: 0.8625 - val_loss: 0.3754
# Epoch 2/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8675 - loss: 0.3574 - val_accuracy: 0.8945 - val_loss: 0.2981
# Epoch 3/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8993 - loss: 0.2806 - val_accuracy: 0.9094 - val_loss: 0.2555
# Epoch 4/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9137 - loss: 0.2430 - val_accuracy: 0.9183 - val_loss: 0.2292
# Epoch 5/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9236 - loss: 0.2148 - val_accuracy: 0.9275 - val_loss: 0.2069
# Epoch 6/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9350 - loss: 0.1878 - val_accuracy: 0.9333 - val_loss: 0.1874
# Epoch 7/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9412 - loss: 0.1726 - val_accuracy: 0.9363 - val_loss: 0.1788
# Epoch 8/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9449 - loss: 0.1602 - val_accuracy: 0.9375 - val_loss: 0.1759
# Epoch 9/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9488 - loss: 0.1483 - val_accuracy: 0.9359 - val_loss: 0.1833
# Epoch 10/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9519 - loss: 0.1384 - val_accuracy: 0.9444 - val_loss: 0.1614
# Epoch 11/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9568 - loss: 0.1270 - val_accuracy: 0.9432 - val_loss: 0.1583
# Epoch 12/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9585 - loss: 0.1203 - val_accuracy: 0.9450 - val_loss: 0.1598
# Epoch 13/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9594 - loss: 0.1178 - val_accuracy: 0.9455 - val_loss: 0.1596
# Epoch 14/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9629 - loss: 0.1080 - val_accuracy: 0.9458 - val_loss: 0.1650
# Epoch 15/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9641 - loss: 0.1040 - val_accuracy: 0.9447 - val_loss: 0.1637
# Epoch 16/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9645 - loss: 0.1003 - val_accuracy: 0.9477 - val_loss: 0.1580
# Epoch 17/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9661 - loss: 0.0973 - val_accuracy: 0.9488 - val_loss: 0.1472
# Epoch 18/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9692 - loss: 0.0923 - val_accuracy: 0.9369 - val_loss: 0.1823
# Epoch 19/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9712 - loss: 0.0844 - val_accuracy: 0.9479 - val_loss: 0.1578
# Epoch 20/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9707 - loss: 0.0834 - val_accuracy: 0.9504 - val_loss: 0.1502
# Epoch 21/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9709 - loss: 0.0839 - val_accuracy: 0.9519 - val_loss: 0.1446
# Epoch 22/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9729 - loss: 0.0782 - val_accuracy: 0.9487 - val_loss: 0.1551
# Epoch 23/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9743 - loss: 0.0760 - val_accuracy: 0.9535 - val_loss: 0.1448
# Epoch 24/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9754 - loss: 0.0725 - val_accuracy: 0.9538 - val_loss: 0.1436
# Epoch 25/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9770 - loss: 0.0698 - val_accuracy: 0.9560 - val_loss: 0.1392
# Epoch 26/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9762 - loss: 0.0706 - val_accuracy: 0.9549 - val_loss: 0.1431
# Epoch 27/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9770 - loss: 0.0654 - val_accuracy: 0.9544 - val_loss: 0.1446
# Epoch 28/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9779 - loss: 0.0663 - val_accuracy: 0.9550 - val_loss: 0.1502
# Epoch 29/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9790 - loss: 0.0616 - val_accuracy: 0.9554 - val_loss: 0.1451
# Epoch 30/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9797 - loss: 0.0588 - val_accuracy: 0.9528 - val_loss: 0.1664
# Epoch 31/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9798 - loss: 0.0597 - val_accuracy: 0.9538 - val_loss: 0.1496
# Epoch 32/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9798 - loss: 0.0592 - val_accuracy: 0.9555 - val_loss: 0.1446
# Epoch 33/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9824 - loss: 0.0542 - val_accuracy: 0.9593 - val_loss: 0.1394
# Epoch 34/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9811 - loss: 0.0564 - val_accuracy: 0.9523 - val_loss: 0.1588
# Epoch 35/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9817 - loss: 0.0552 - val_accuracy: 0.9582 - val_loss: 0.1431
# Epoch 36/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9826 - loss: 0.0505 - val_accuracy: 0.9570 - val_loss: 0.1466
# Epoch 37/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9820 - loss: 0.0524 - val_accuracy: 0.9563 - val_loss: 0.1541
# Epoch 38/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9830 - loss: 0.0484 - val_accuracy: 0.9568 - val_loss: 0.1561
# Epoch 39/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9846 - loss: 0.0464 - val_accuracy: 0.9477 - val_loss: 0.1767
# Epoch 40/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9832 - loss: 0.0486 - val_accuracy: 0.9575 - val_loss: 0.1545
# Epoch 41/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9849 - loss: 0.0450 - val_accuracy: 0.9585 - val_loss: 0.1509
# Epoch 42/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9848 - loss: 0.0459 - val_accuracy: 0.9549 - val_loss: 0.1600
# Epoch 43/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9846 - loss: 0.0464 - val_accuracy: 0.9610 - val_loss: 0.1409
# Epoch 44/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9852 - loss: 0.0438 - val_accuracy: 0.9585 - val_loss: 0.1561
# Epoch 45/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9836 - loss: 0.0462 - val_accuracy: 0.9590 - val_loss: 0.1553
# Epoch 46/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9862 - loss: 0.0407 - val_accuracy: 0.9548 - val_loss: 0.1735
# Epoch 47/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9871 - loss: 0.0393 - val_accuracy: 0.9587 - val_loss: 0.1678
# Epoch 48/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9857 - loss: 0.0414 - val_accuracy: 0.9571 - val_loss: 0.1661
# Epoch 49/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9870 - loss: 0.0397 - val_accuracy: 0.9576 - val_loss: 0.1671
# Epoch 50/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9872 - loss: 0.0377 - val_accuracy: 0.9578 - val_loss: 0.1616
# Epoch 51/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9871 - loss: 0.0385 - val_accuracy: 0.9575 - val_loss: 0.1700
# Epoch 52/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9875 - loss: 0.0373 - val_accuracy: 0.9570 - val_loss: 0.1774
# Epoch 53/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9878 - loss: 0.0345 - val_accuracy: 0.9594 - val_loss: 0.1664
# Epoch 54/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9870 - loss: 0.0369 - val_accuracy: 0.9565 - val_loss: 0.1759
# Epoch 55/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9876 - loss: 0.0360 - val_accuracy: 0.9553 - val_loss: 0.1741
# Epoch 56/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9885 - loss: 0.0347 - val_accuracy: 0.9595 - val_loss: 0.1629
# Epoch 57/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9884 - loss: 0.0339 - val_accuracy: 0.9605 - val_loss: 0.1631
# Epoch 58/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9895 - loss: 0.0321 - val_accuracy: 0.9580 - val_loss: 0.1741
# Epoch 59/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9878 - loss: 0.0337 - val_accuracy: 0.9603 - val_loss: 0.1605
# Epoch 60/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9896 - loss: 0.0311 - val_accuracy: 0.9609 - val_loss: 0.1637
# Epoch 61/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9890 - loss: 0.0330 - val_accuracy: 0.9595 - val_loss: 0.1662
# Epoch 62/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9900 - loss: 0.0314 - val_accuracy: 0.9611 - val_loss: 0.1700
# Epoch 63/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9894 - loss: 0.0315 - val_accuracy: 0.9592 - val_loss: 0.1712
# Epoch 64/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9892 - loss: 0.0328 - val_accuracy: 0.9587 - val_loss: 0.1786
# Epoch 65/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9903 - loss: 0.0289 - val_accuracy: 0.9605 - val_loss: 0.1706
# Epoch 66/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9895 - loss: 0.0293 - val_accuracy: 0.9610 - val_loss: 0.1659
# Epoch 67/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9918 - loss: 0.0251 - val_accuracy: 0.9554 - val_loss: 0.1979
# Epoch 68/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9894 - loss: 0.0319 - val_accuracy: 0.9601 - val_loss: 0.1733
# Epoch 69/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9899 - loss: 0.0306 - val_accuracy: 0.9603 - val_loss: 0.1749
# Epoch 70/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9897 - loss: 0.0306 - val_accuracy: 0.9610 - val_loss: 0.1832
# Epoch 71/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9910 - loss: 0.0267 - val_accuracy: 0.9553 - val_loss: 0.2055
# Epoch 72/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9901 - loss: 0.0304 - val_accuracy: 0.9598 - val_loss: 0.1935
# Epoch 73/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9892 - loss: 0.0308 - val_accuracy: 0.9618 - val_loss: 0.1689
# Epoch 74/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9911 - loss: 0.0256 - val_accuracy: 0.9609 - val_loss: 0.1807
# Epoch 75/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9912 - loss: 0.0259 - val_accuracy: 0.9601 - val_loss: 0.1941
# Epoch 76/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9906 - loss: 0.0287 - val_accuracy: 0.9617 - val_loss: 0.1770
# Epoch 77/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9918 - loss: 0.0240 - val_accuracy: 0.9635 - val_loss: 0.1754
# Epoch 78/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9913 - loss: 0.0243 - val_accuracy: 0.9599 - val_loss: 0.1927
# Epoch 79/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9913 - loss: 0.0256 - val_accuracy: 0.9638 - val_loss: 0.1728
# Epoch 80/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9917 - loss: 0.0241 - val_accuracy: 0.9625 - val_loss: 0.1868
# Epoch 81/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9916 - loss: 0.0235 - val_accuracy: 0.9637 - val_loss: 0.1768
# Epoch 82/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9921 - loss: 0.0235 - val_accuracy: 0.9615 - val_loss: 0.1849
# Epoch 83/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9917 - loss: 0.0250 - val_accuracy: 0.9629 - val_loss: 0.1811
# Epoch 84/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9915 - loss: 0.0258 - val_accuracy: 0.9630 - val_loss: 0.1823
# Epoch 85/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9921 - loss: 0.0243 - val_accuracy: 0.9630 - val_loss: 0.1781
# Epoch 86/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9928 - loss: 0.0209 - val_accuracy: 0.9625 - val_loss: 0.1857
# Epoch 87/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9919 - loss: 0.0247 - val_accuracy: 0.9630 - val_loss: 0.1889
# Epoch 88/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9919 - loss: 0.0233 - val_accuracy: 0.9618 - val_loss: 0.1976
# Epoch 89/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9929 - loss: 0.0214 - val_accuracy: 0.9623 - val_loss: 0.1905
# Epoch 90/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9934 - loss: 0.0209 - val_accuracy: 0.9595 - val_loss: 0.1945
# Epoch 91/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9906 - loss: 0.0267 - val_accuracy: 0.9635 - val_loss: 0.1797
# Epoch 92/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9928 - loss: 0.0205 - val_accuracy: 0.9610 - val_loss: 0.2003
# Epoch 93/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9919 - loss: 0.0245 - val_accuracy: 0.9629 - val_loss: 0.1870
# Epoch 94/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9928 - loss: 0.0206 - val_accuracy: 0.9596 - val_loss: 0.2098
# Epoch 95/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9917 - loss: 0.0241 - val_accuracy: 0.9634 - val_loss: 0.1913
# Epoch 96/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9930 - loss: 0.0208 - val_accuracy: 0.9618 - val_loss: 0.1958
# Epoch 97/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9919 - loss: 0.0217 - val_accuracy: 0.9638 - val_loss: 0.1884
# Epoch 98/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9932 - loss: 0.0198 - val_accuracy: 0.9638 - val_loss: 0.1940
# Epoch 99/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9936 - loss: 0.0201 - val_accuracy: 0.9572 - val_loss: 0.2265
# Epoch 100/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9923 - loss: 0.0236 - val_accuracy: 0.9617 - val_loss: 0.2045
# Epoch 101/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9944 - loss: 0.0175 - val_accuracy: 0.9600 - val_loss: 0.2122
# Epoch 102/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9917 - loss: 0.0270 - val_accuracy: 0.9615 - val_loss: 0.2050
# Epoch 103/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9945 - loss: 0.0163 - val_accuracy: 0.9611 - val_loss: 0.2091
# Epoch 104/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9939 - loss: 0.0184 - val_accuracy: 0.9630 - val_loss: 0.2033
# Epoch 105/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9920 - loss: 0.0219 - val_accuracy: 0.9638 - val_loss: 0.2022
# Epoch 106/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9946 - loss: 0.0162 - val_accuracy: 0.9617 - val_loss: 0.2113
# Epoch 107/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9947 - loss: 0.0166 - val_accuracy: 0.9621 - val_loss: 0.2158
# Epoch 108/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9935 - loss: 0.0192 - val_accuracy: 0.9615 - val_loss: 0.2014
# Epoch 109/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9943 - loss: 0.0166 - val_accuracy: 0.9627 - val_loss: 0.2039
# Epoch 110/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9939 - loss: 0.0182 - val_accuracy: 0.9617 - val_loss: 0.2160
# Epoch 111/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9914 - loss: 0.0249 - val_accuracy: 0.9642 - val_loss: 0.2011
# Epoch 112/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9932 - loss: 0.0204 - val_accuracy: 0.9655 - val_loss: 0.1956
# Epoch 113/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9930 - loss: 0.0211 - val_accuracy: 0.9616 - val_loss: 0.2147
# Epoch 114/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9940 - loss: 0.0188 - val_accuracy: 0.9605 - val_loss: 0.2243
# Epoch 115/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9930 - loss: 0.0218 - val_accuracy: 0.9637 - val_loss: 0.2004
# Epoch 116/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9926 - loss: 0.0225 - val_accuracy: 0.9650 - val_loss: 0.1995
# Epoch 117/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9950 - loss: 0.0154 - val_accuracy: 0.9631 - val_loss: 0.2050
# Epoch 118/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9939 - loss: 0.0175 - val_accuracy: 0.9628 - val_loss: 0.2037
# Epoch 119/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9940 - loss: 0.0186 - val_accuracy: 0.9624 - val_loss: 0.2234
# Epoch 120/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9947 - loss: 0.0161 - val_accuracy: 0.9655 - val_loss: 0.2098
# Epoch 121/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9937 - loss: 0.0184 - val_accuracy: 0.9632 - val_loss: 0.2088
# Epoch 122/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.9612 - val_loss: 0.2168
# Epoch 123/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9921 - loss: 0.0238 - val_accuracy: 0.9628 - val_loss: 0.2211
# Epoch 124/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9948 - loss: 0.0169 - val_accuracy: 0.9625 - val_loss: 0.2044
# Epoch 125/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9943 - loss: 0.0175 - val_accuracy: 0.9647 - val_loss: 0.2187
# Epoch 126/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9929 - loss: 0.0211 - val_accuracy: 0.9670 - val_loss: 0.1900
# Epoch 127/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9951 - loss: 0.0150 - val_accuracy: 0.9595 - val_loss: 0.2334
# Epoch 128/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9921 - loss: 0.0239 - val_accuracy: 0.9658 - val_loss: 0.2063
# Epoch 129/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9952 - loss: 0.0142 - val_accuracy: 0.9640 - val_loss: 0.2173
# Epoch 130/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9932 - loss: 0.0204 - val_accuracy: 0.9606 - val_loss: 0.2243
# Epoch 131/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9954 - loss: 0.0132 - val_accuracy: 0.9624 - val_loss: 0.2216
# Epoch 132/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9938 - loss: 0.0184 - val_accuracy: 0.9621 - val_loss: 0.2115
# Epoch 133/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9945 - loss: 0.0168 - val_accuracy: 0.9615 - val_loss: 0.2185
# Epoch 134/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9944 - loss: 0.0166 - val_accuracy: 0.9607 - val_loss: 0.2194
# Epoch 135/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9954 - loss: 0.0149 - val_accuracy: 0.9612 - val_loss: 0.2352
# Epoch 136/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9939 - loss: 0.0187 - val_accuracy: 0.9649 - val_loss: 0.2234
# Epoch 137/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9939 - loss: 0.0169 - val_accuracy: 0.9638 - val_loss: 0.2220
# Epoch 138/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9939 - loss: 0.0184 - val_accuracy: 0.9630 - val_loss: 0.2212
# Epoch 139/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.9649 - val_loss: 0.2113
# Epoch 140/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9948 - loss: 0.0157 - val_accuracy: 0.9661 - val_loss: 0.2169
# Epoch 141/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9949 - loss: 0.0152 - val_accuracy: 0.9610 - val_loss: 0.2377
# Epoch 142/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9945 - loss: 0.0166 - val_accuracy: 0.9629 - val_loss: 0.2369
# Epoch 143/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9940 - loss: 0.0168 - val_accuracy: 0.9650 - val_loss: 0.2147
# Epoch 144/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9957 - loss: 0.0130 - val_accuracy: 0.9654 - val_loss: 0.2130
# Epoch 145/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9952 - loss: 0.0146 - val_accuracy: 0.9628 - val_loss: 0.2207
# Epoch 146/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9938 - loss: 0.0189 - val_accuracy: 0.9608 - val_loss: 0.2313
# Epoch 147/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9933 - loss: 0.0209 - val_accuracy: 0.9656 - val_loss: 0.2134
# Epoch 148/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9954 - loss: 0.0131 - val_accuracy: 0.9633 - val_loss: 0.2283
# Epoch 149/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9955 - loss: 0.0133 - val_accuracy: 0.9604 - val_loss: 0.2448
# Epoch 150/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9936 - loss: 0.0184 - val_accuracy: 0.9654 - val_loss: 0.2224
# Epoch 151/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9959 - loss: 0.0120 - val_accuracy: 0.9644 - val_loss: 0.2280
# Epoch 152/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9959 - loss: 0.0128 - val_accuracy: 0.9642 - val_loss: 0.2248
# Epoch 153/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9957 - loss: 0.0145 - val_accuracy: 0.9610 - val_loss: 0.2310
# Epoch 154/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9949 - loss: 0.0148 - val_accuracy: 0.9607 - val_loss: 0.2652
# Epoch 155/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9939 - loss: 0.0181 - val_accuracy: 0.9661 - val_loss: 0.2221
# Epoch 156/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9958 - loss: 0.0126 - val_accuracy: 0.9661 - val_loss: 0.2265
# Epoch 157/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9956 - loss: 0.0131 - val_accuracy: 0.9583 - val_loss: 0.2506
# Epoch 158/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9934 - loss: 0.0201 - val_accuracy: 0.9668 - val_loss: 0.2169
# Epoch 159/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9958 - loss: 0.0123 - val_accuracy: 0.9607 - val_loss: 0.2438
# Epoch 160/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9950 - loss: 0.0143 - val_accuracy: 0.9608 - val_loss: 0.2444
# Epoch 161/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9937 - loss: 0.0211 - val_accuracy: 0.9625 - val_loss: 0.2368
# Epoch 162/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9963 - loss: 0.0112 - val_accuracy: 0.9620 - val_loss: 0.2431
# Epoch 163/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9956 - loss: 0.0136 - val_accuracy: 0.9635 - val_loss: 0.2417
# Epoch 164/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9952 - loss: 0.0138 - val_accuracy: 0.9612 - val_loss: 0.2494
# Epoch 165/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9944 - loss: 0.0164 - val_accuracy: 0.9654 - val_loss: 0.2297
# Epoch 166/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9953 - loss: 0.0144 - val_accuracy: 0.9636 - val_loss: 0.2344
# Epoch 167/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9952 - loss: 0.0143 - val_accuracy: 0.9602 - val_loss: 0.2455
# Epoch 168/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9960 - loss: 0.0130 - val_accuracy: 0.9661 - val_loss: 0.2161
# Epoch 169/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9948 - loss: 0.0159 - val_accuracy: 0.9620 - val_loss: 0.2603
# Epoch 170/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9955 - loss: 0.0133 - val_accuracy: 0.9661 - val_loss: 0.2228
# Epoch 171/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9605 - val_loss: 0.2653
# Epoch 172/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9952 - loss: 0.0159 - val_accuracy: 0.9639 - val_loss: 0.2376
# Epoch 173/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9957 - loss: 0.0147 - val_accuracy: 0.9627 - val_loss: 0.2438
# Epoch 174/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9962 - loss: 0.0107 - val_accuracy: 0.9606 - val_loss: 0.2535
# Epoch 175/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9939 - loss: 0.0174 - val_accuracy: 0.9619 - val_loss: 0.2379
# Epoch 176/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9959 - loss: 0.0141 - val_accuracy: 0.9641 - val_loss: 0.2351
# Epoch 177/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9971 - loss: 0.0087 - val_accuracy: 0.9665 - val_loss: 0.2208
# Epoch 178/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9945 - loss: 0.0168 - val_accuracy: 0.9653 - val_loss: 0.2347
# Epoch 179/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.9635 - val_loss: 0.2439
# Epoch 180/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9970 - loss: 0.0093 - val_accuracy: 0.9639 - val_loss: 0.2259
# Epoch 181/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9965 - loss: 0.0104 - val_accuracy: 0.9620 - val_loss: 0.2516
# Epoch 182/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9950 - loss: 0.0158 - val_accuracy: 0.9661 - val_loss: 0.2242
# Epoch 183/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9965 - loss: 0.0112 - val_accuracy: 0.9670 - val_loss: 0.2206
# Epoch 184/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9640 - val_loss: 0.2452
# Epoch 185/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9934 - loss: 0.0207 - val_accuracy: 0.9643 - val_loss: 0.2347
# Epoch 186/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9959 - loss: 0.0120 - val_accuracy: 0.9658 - val_loss: 0.2300
# Epoch 187/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9966 - loss: 0.0112 - val_accuracy: 0.9619 - val_loss: 0.2577
# Epoch 188/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9947 - loss: 0.0168 - val_accuracy: 0.9636 - val_loss: 0.2429
# Epoch 189/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9962 - loss: 0.0116 - val_accuracy: 0.9637 - val_loss: 0.2446
# Epoch 190/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9963 - loss: 0.0127 - val_accuracy: 0.9634 - val_loss: 0.2474
# Epoch 191/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9952 - loss: 0.0142 - val_accuracy: 0.9629 - val_loss: 0.2495
# Epoch 192/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9963 - loss: 0.0119 - val_accuracy: 0.9657 - val_loss: 0.2349
# Epoch 193/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9958 - loss: 0.0127 - val_accuracy: 0.9609 - val_loss: 0.2681
# Epoch 194/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9936 - loss: 0.0199 - val_accuracy: 0.9650 - val_loss: 0.2374
# Epoch 195/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.9615 - val_loss: 0.2472
# Epoch 196/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9963 - loss: 0.0111 - val_accuracy: 0.9643 - val_loss: 0.2373
# Epoch 197/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9966 - loss: 0.0101 - val_accuracy: 0.9617 - val_loss: 0.2766
# Epoch 198/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9965 - loss: 0.0102 - val_accuracy: 0.9645 - val_loss: 0.2364
# Epoch 199/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9946 - loss: 0.0167 - val_accuracy: 0.9633 - val_loss: 0.2429
# Epoch 200/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9954 - loss: 0.0140 - val_accuracy: 0.9635 - val_loss: 0.2525
# Epoch 201/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9975 - loss: 0.0083 - val_accuracy: 0.9647 - val_loss: 0.2443
# Epoch 202/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9957 - loss: 0.0120 - val_accuracy: 0.9599 - val_loss: 0.2734
# Epoch 203/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9955 - loss: 0.0149 - val_accuracy: 0.9655 - val_loss: 0.2370
# Epoch 204/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9954 - loss: 0.0140 - val_accuracy: 0.9661 - val_loss: 0.2383
# Epoch 205/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9966 - loss: 0.0105 - val_accuracy: 0.9632 - val_loss: 0.2478
# Epoch 206/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9960 - loss: 0.0124 - val_accuracy: 0.9659 - val_loss: 0.2511
# Epoch 207/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9960 - loss: 0.0129 - val_accuracy: 0.9668 - val_loss: 0.2373
# Epoch 208/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9969 - loss: 0.0109 - val_accuracy: 0.9653 - val_loss: 0.2486
# Epoch 209/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.9649 - val_loss: 0.2378
# Epoch 210/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9950 - loss: 0.0143 - val_accuracy: 0.9640 - val_loss: 0.2525
# Epoch 211/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9956 - loss: 0.0125 - val_accuracy: 0.9636 - val_loss: 0.2631
# Epoch 212/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9947 - loss: 0.0177 - val_accuracy: 0.9638 - val_loss: 0.2618
# Epoch 213/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9967 - loss: 0.0099 - val_accuracy: 0.9613 - val_loss: 0.2665
# Epoch 214/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9956 - loss: 0.0142 - val_accuracy: 0.9644 - val_loss: 0.2460
# Epoch 215/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9648 - val_loss: 0.2508
# Epoch 216/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9965 - loss: 0.0109 - val_accuracy: 0.9641 - val_loss: 0.2576
# Epoch 217/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9960 - loss: 0.0129 - val_accuracy: 0.9618 - val_loss: 0.2686
# Epoch 218/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9967 - loss: 0.0113 - val_accuracy: 0.9653 - val_loss: 0.2395
# Epoch 219/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9961 - loss: 0.0115 - val_accuracy: 0.9639 - val_loss: 0.2514
# Epoch 220/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9966 - loss: 0.0105 - val_accuracy: 0.9625 - val_loss: 0.2612
# Epoch 221/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9975 - loss: 0.0074 - val_accuracy: 0.9640 - val_loss: 0.2546
# Epoch 222/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9955 - loss: 0.0136 - val_accuracy: 0.9663 - val_loss: 0.2449
# Epoch 223/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9954 - loss: 0.0150 - val_accuracy: 0.9661 - val_loss: 0.2355
# Epoch 224/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9977 - loss: 0.0069 - val_accuracy: 0.9667 - val_loss: 0.2479
# Epoch 225/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9961 - loss: 0.0134 - val_accuracy: 0.9663 - val_loss: 0.2366
# Epoch 226/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9971 - loss: 0.0088 - val_accuracy: 0.9621 - val_loss: 0.2704
# Epoch 227/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9958 - loss: 0.0129 - val_accuracy: 0.9670 - val_loss: 0.2374
# Epoch 228/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9965 - loss: 0.0108 - val_accuracy: 0.9639 - val_loss: 0.2549
# Epoch 229/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9972 - loss: 0.0097 - val_accuracy: 0.9644 - val_loss: 0.2551
# Epoch 230/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9953 - loss: 0.0144 - val_accuracy: 0.9657 - val_loss: 0.2498
# Epoch 231/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9963 - loss: 0.0128 - val_accuracy: 0.9642 - val_loss: 0.2668
# Epoch 232/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9959 - loss: 0.0138 - val_accuracy: 0.9648 - val_loss: 0.2526
# Epoch 233/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9961 - loss: 0.0120 - val_accuracy: 0.9646 - val_loss: 0.2499
# Epoch 234/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.9663 - val_loss: 0.2458
# Epoch 235/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9944 - loss: 0.0196 - val_accuracy: 0.9640 - val_loss: 0.2779
# Epoch 236/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.9644 - val_loss: 0.2611
# Epoch 237/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9956 - loss: 0.0128 - val_accuracy: 0.9626 - val_loss: 0.2761
# Epoch 238/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9966 - loss: 0.0101 - val_accuracy: 0.9610 - val_loss: 0.2764
# Epoch 239/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9959 - loss: 0.0122 - val_accuracy: 0.9636 - val_loss: 0.2704
# Epoch 240/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9969 - loss: 0.0099 - val_accuracy: 0.9643 - val_loss: 0.2659
# Epoch 241/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9954 - loss: 0.0147 - val_accuracy: 0.9670 - val_loss: 0.2495
# Epoch 242/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9968 - loss: 0.0091 - val_accuracy: 0.9653 - val_loss: 0.2653
# Epoch 243/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9963 - loss: 0.0102 - val_accuracy: 0.9674 - val_loss: 0.2441
# Epoch 244/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9965 - loss: 0.0108 - val_accuracy: 0.9636 - val_loss: 0.2686
# Epoch 245/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9961 - loss: 0.0149 - val_accuracy: 0.9655 - val_loss: 0.2655
# Epoch 246/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9974 - loss: 0.0076 - val_accuracy: 0.9612 - val_loss: 0.2743
# Epoch 247/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9958 - loss: 0.0133 - val_accuracy: 0.9650 - val_loss: 0.2501
# Epoch 248/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9973 - loss: 0.0086 - val_accuracy: 0.9640 - val_loss: 0.2649
# Epoch 249/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.9653 - val_loss: 0.2648
# Epoch 250/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9979 - loss: 0.0068 - val_accuracy: 0.9658 - val_loss: 0.2585
# Epoch 251/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9974 - loss: 0.0077 - val_accuracy: 0.9658 - val_loss: 0.2499
# Epoch 252/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9969 - loss: 0.0103 - val_accuracy: 0.9659 - val_loss: 0.2604
# Epoch 253/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9970 - loss: 0.0088 - val_accuracy: 0.9653 - val_loss: 0.2598
# Epoch 254/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9979 - loss: 0.0059 - val_accuracy: 0.9617 - val_loss: 0.2756
# Epoch 255/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9954 - loss: 0.0155 - val_accuracy: 0.9616 - val_loss: 0.2795
# Epoch 256/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9981 - loss: 0.0066 - val_accuracy: 0.9643 - val_loss: 0.2672
# Epoch 257/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9965 - loss: 0.0107 - val_accuracy: 0.9600 - val_loss: 0.2747
# Epoch 258/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9957 - loss: 0.0130 - val_accuracy: 0.9686 - val_loss: 0.2362
# Epoch 259/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9979 - loss: 0.0063 - val_accuracy: 0.9634 - val_loss: 0.2766
# Epoch 260/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9945 - loss: 0.0176 - val_accuracy: 0.9673 - val_loss: 0.2473
# Epoch 261/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9660 - val_loss: 0.2572
# Epoch 262/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9972 - loss: 0.0091 - val_accuracy: 0.9645 - val_loss: 0.2678
# Epoch 263/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9965 - loss: 0.0115 - val_accuracy: 0.9672 - val_loss: 0.2549
# Epoch 264/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9970 - loss: 0.0092 - val_accuracy: 0.9650 - val_loss: 0.2620
# Epoch 265/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9969 - loss: 0.0100 - val_accuracy: 0.9639 - val_loss: 0.2734
# Epoch 266/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9964 - loss: 0.0114 - val_accuracy: 0.9653 - val_loss: 0.2622
# Epoch 267/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9954 - loss: 0.0125 - val_accuracy: 0.9656 - val_loss: 0.2534
# Epoch 268/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9977 - loss: 0.0067 - val_accuracy: 0.9661 - val_loss: 0.2599
# Epoch 269/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9631 - val_loss: 0.2695
# Epoch 270/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9969 - loss: 0.0100 - val_accuracy: 0.9629 - val_loss: 0.2872
# Epoch 271/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9963 - loss: 0.0124 - val_accuracy: 0.9682 - val_loss: 0.2576
# Epoch 272/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9969 - loss: 0.0100 - val_accuracy: 0.9616 - val_loss: 0.2884
# Epoch 273/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9969 - loss: 0.0094 - val_accuracy: 0.9647 - val_loss: 0.2719
# Epoch 274/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9972 - loss: 0.0091 - val_accuracy: 0.9651 - val_loss: 0.2718
# Epoch 275/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9972 - loss: 0.0086 - val_accuracy: 0.9662 - val_loss: 0.2690
# Epoch 276/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9962 - loss: 0.0111 - val_accuracy: 0.9663 - val_loss: 0.2517
# Epoch 277/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9972 - loss: 0.0086 - val_accuracy: 0.9633 - val_loss: 0.2834
# Epoch 278/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9956 - loss: 0.0141 - val_accuracy: 0.9637 - val_loss: 0.2726
# Epoch 279/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9972 - loss: 0.0084 - val_accuracy: 0.9613 - val_loss: 0.3010
# Epoch 280/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9957 - loss: 0.0148 - val_accuracy: 0.9665 - val_loss: 0.2510
# Epoch 281/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9975 - loss: 0.0083 - val_accuracy: 0.9638 - val_loss: 0.2700
# Epoch 282/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9981 - loss: 0.0061 - val_accuracy: 0.9649 - val_loss: 0.2718
# Epoch 283/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9966 - loss: 0.0112 - val_accuracy: 0.9642 - val_loss: 0.2676
# Epoch 284/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9960 - loss: 0.0120 - val_accuracy: 0.9650 - val_loss: 0.2874
# Epoch 285/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9966 - loss: 0.0096 - val_accuracy: 0.9625 - val_loss: 0.2833
# Epoch 286/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9976 - loss: 0.0074 - val_accuracy: 0.9670 - val_loss: 0.2593
# Epoch 287/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9976 - loss: 0.0081 - val_accuracy: 0.9639 - val_loss: 0.2690
# Epoch 288/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9973 - loss: 0.0088 - val_accuracy: 0.9663 - val_loss: 0.2586
# Epoch 289/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9968 - loss: 0.0100 - val_accuracy: 0.9657 - val_loss: 0.2680
# Epoch 290/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.9661 - val_loss: 0.2728
# Epoch 291/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9968 - loss: 0.0104 - val_accuracy: 0.9611 - val_loss: 0.3037
# Epoch 292/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9644 - val_loss: 0.2788
# Epoch 293/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9967 - loss: 0.0107 - val_accuracy: 0.9656 - val_loss: 0.2689
# Epoch 294/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9983 - loss: 0.0056 - val_accuracy: 0.9656 - val_loss: 0.2734
# Epoch 295/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9970 - loss: 0.0089 - val_accuracy: 0.9658 - val_loss: 0.2561
# Epoch 296/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9980 - loss: 0.0069 - val_accuracy: 0.9621 - val_loss: 0.3189
# Epoch 297/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9967 - loss: 0.0097 - val_accuracy: 0.9645 - val_loss: 0.2815
# Epoch 298/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9626 - val_loss: 0.2928
# Epoch 299/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9953 - loss: 0.0156 - val_accuracy: 0.9618 - val_loss: 0.3110
# Epoch 300/300
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9966 - loss: 0.0113 - val_accuracy: 0.9661 - val_loss: 0.2734
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Test Accuracy (Overall): 96.78%
#                                                 precision    recall  f1-score   support
#
#                                N - Normal Beat       0.94      0.95      0.95      5982
#                          Q - Unclassified beat       0.99      0.99      0.99      5959
#          V - Premature ventricular contraction       0.97      0.98      0.97      5983
# S - Supraventricular premature or ectopic beat       0.96      0.96      0.96      5986
#      F - Fusion of ventricular and normal beat       0.98      0.96      0.97      6090
#
#                                       accuracy                           0.97     30000
#                                      macro avg       0.97      0.97      0.97     30000
#                                   weighted avg       0.97      0.97      0.97     30000
#
# Test Accuracy of N - Normal Beat: 94.93% (5982/30000)
# Test Accuracy of Q - Unclassified beat: 99.26% (5959/30000)
# Test Accuracy of V - Premature ventricular contraction: 97.64% (5983/30000)
# Test Accuracy of S - Supraventricular premature or ectopic beat: 95.97% (5986/30000)
# Test Accuracy of F - Fusion of ventricular and normal beat: 96.12% (6090/30000)

# %%
from sklearn.metrics import confusion_matrix

# Prepare the mapping for the labels
label_mapping = {label: idx for idx, label in enumerate(labels_resampled.unique())}
labels_numeric = labels_resampled_final.map(label_mapping).values

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=list(label_mapping.values()))

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[5679   23   43  177   60]
#  [  18 5915   19    4    3]
#  [  36   13 5842   26   66]
#  [ 200   17   17 5745    7]
#  [  84    6  126   20 5854]]

# %%
cm
# Out:
# array([[5679,   23,   43,  177,   60],
#        [  18, 5915,   19,    4,    3],
#        [  36,   13, 5842,   26,   66],
#        [ 200,   17,   17, 5745,    7],
#        [  84,    6,  126,   20, 5854]])
